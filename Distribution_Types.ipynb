# %% [markdown]
# <a href="https://colab.research.google.com/github/TatKhachatryan/Distribution-Visualizations/blob/main/Distribution_Types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# visualization 
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# distributions
from scipy.stats import norm
from scipy.stats import lognorm
from scipy.stats import binom

# %% [markdown]
# ### Normal Distribution

# %%
# now lets generate random variables betweem -10, 10
x = np.linspace(-10, 10, 100)

plt.figure(figsize=(8, 6))

# normal distribution takes 2 parameters: mean, std and pdf is Probability Density Function

plt.plot(norm(0, 1).pdf(x), label='Params: 0, 1')
plt.plot(norm(0, 2).pdf(x), label='Params: 0, 2')
plt.plot(norm(1, 3).pdf(x), label='Params: 1, 3')
plt.title('Standard Normal Distribution')
plt.xlabel('Values of Random variable X')
plt.ylabel('Probability')

plt.legend()
plt.show()

# %% [markdown]
# ### Log-normal distribution

# %%
# Varying positional arguments 
plt.figure(figsize=(8, 6))

x = np.linspace(0, 5, 100)
y1 = lognorm.pdf(x, 1, 3) 
y2 = lognorm.pdf(x, 1, 4) 
plt.plot(x, y1, "*", label='Params: 1, 3')
plt.plot(x, y2, "--", label='Params: 1, 4')
plt.title('Log-normal Distribution')
plt.xlabel('Values of Random Variable X')
plt.ylabel('Probability')
plt.legend()
plt.show()

# %% [markdown]
# ### Binomial Distribution

# %%
n = 12
p = 0.2
x = np.arange(0, n+1)

binomial_pmf = binom.pmf(x, n, p)
binomial_pmf
# Out:
# array([6.87194767e-02, 2.06158430e-01, 2.83467842e-01, 2.36223201e-01,
#        1.32875551e-01, 5.31502203e-02, 1.55021476e-02, 3.32188877e-03,
#        5.19045120e-04, 5.76716800e-05, 4.32537600e-06, 1.96608000e-07,
#        4.09600000e-09])

# %%
plt.figure(figsize=(8, 6))
plt.plot(x, binomial_pmf)
plt.title(f'Binomial Distribution, (n={n}, p={p})')
plt.xlabel('Values')
plt.ylabel('Probability')

plt.show()
